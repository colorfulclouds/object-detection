# %%
import cv2

import matplotlib.pyplot as plt

# %matplotlib inline

import numpy as np

import selectivesearch as ss

# %%
arr = cv2.imread('../RCNN/cat_and_dog/cat.0.jpg')

arr=arr[:,:,[2,1,0]]

plt.imshow(arr)

# %%
a , b = ss.selective_search(arr)

# %%
b
# Out:
# [{'labels': [0.0], 'rect': (0, 0, 3, 47), 'size': 152},
#  {'labels': [1.0], 'rect': (3, 0, 1, 47), 'size': 88},
#  {'labels': [2.0], 'rect': (5, 0, 5, 48), 'size': 161},
#  {'labels': [3.0], 'rect': (6, 0, 6, 15), 'size': 112},
#  {'labels': [4.0], 'rect': (9, 0, 13, 47), 'size': 396},
#  {'labels': [5.0], 'rect': (19, 0, 5, 15), 'size': 81},
#  {'labels': [6.0], 'rect': (24, 0, 5, 15), 'size': 79},
#  {'labels': [7.0], 'rect': (28, 0, 9, 15), 'size': 91},
#  {'labels': [8.0], 'rect': (32, 0, 19, 18), 'size': 192},
#  {'labels': [9.0], 'rect': (51, 0, 11, 8), 'size': 77},
#  {'labels': [10.0], 'rect': (51, 0, 13, 9), 'size': 55},
#  {'labels': [11.0], 'rect': (36, 0, 46, 32), 'size': 225},
#  {'labels': [12.0], 'rect': (66, 0, 18, 39), 'size': 56},
#  {'labels': [13.0], 'rect': (67, 0, 20, 39), 'size': 151},
#  {'labels': [14.0], 'rect': (69, 0, 18, 28), 'size': 160},
#  {'labels': [15.0], 'rect': (72, 0, 26, 36), 'size': 320},
# ...

# %%
b
# Out:
# [{'labels': [0.0], 'rect': (0, 0, 3, 47), 'size': 152},
#  {'labels': [1.0], 'rect': (3, 0, 1, 47), 'size': 88},
#  {'labels': [2.0], 'rect': (5, 0, 5, 48), 'size': 161},
#  {'labels': [3.0], 'rect': (6, 0, 6, 15), 'size': 112},
#  {'labels': [4.0], 'rect': (9, 0, 13, 47), 'size': 396},
#  {'labels': [5.0], 'rect': (19, 0, 5, 15), 'size': 81},
#  {'labels': [6.0], 'rect': (24, 0, 5, 15), 'size': 79},
#  {'labels': [7.0], 'rect': (28, 0, 9, 15), 'size': 91},
#  {'labels': [8.0], 'rect': (32, 0, 19, 18), 'size': 192},
#  {'labels': [9.0], 'rect': (51, 0, 11, 8), 'size': 77},
#  {'labels': [10.0], 'rect': (51, 0, 13, 9), 'size': 55},
#  {'labels': [11.0], 'rect': (36, 0, 46, 32), 'size': 225},
#  {'labels': [12.0], 'rect': (66, 0, 18, 39), 'size': 56},
#  {'labels': [13.0], 'rect': (67, 0, 20, 39), 'size': 151},
#  {'labels': [14.0], 'rect': (69, 0, 18, 28), 'size': 160},
#  {'labels': [15.0], 'rect': (72, 0, 26, 36), 'size': 320},
# ...

# %%
b[0]
# Out:
# {'labels': [0.0], 'rect': (0, 0, 3, 47), 'size': 152}

# %%
b[0]['labels'][0]
# Out:
# 0.0

# %%
plt.imshow(a[:,:,[0,1,2]].astype(np.uint8))

# %%
b=a[:,:,0:3].astype(int)

# %%
plt.imshow(arr)

# %%
b.dtype
# Out:
# dtype('int32')

# %%
arr.dtype
# Out:
# dtype('uint8')

# %%
np.uint8
# Out:
# numpy.uint8
